# %% [markdown]
# # Sorting Algorithms
#
# Understanding sorting algorithms builds intuition for algorithm design and complexity analysis.
#
# ---
#
# ## Overview
#
# | Algorithm | Time (Best) | Time (Avg) | Time (Worst) | Space | Stable |
# |-----------|-------------|------------|--------------|-------|--------|
# | Bubble Sort | O(n) | O(n²) | O(n²) | O(1) | ✅ |
# | Selection Sort | O(n²) | O(n²) | O(n²) | O(1) | ❌ |
# | Insertion Sort | O(n) | O(n²) | O(n²) | O(1) | ✅ |
# | Merge Sort | O(n log n) | O(n log n) | O(n log n) | O(n) | ✅ |
# | Quick Sort | O(n log n) | O(n log n) | O(n²) | O(log n) | ❌ |
# | Heap Sort | O(n log n) | O(n log n) | O(n log n) | O(1) | ❌ |

# %% [markdown]
# ---
#
# ## Bubble Sort
#
# Repeatedly swap adjacent elements if they're in wrong order.

# %%
def bubble_sort(arr):
    """O(n²) time, O(1) space"""
    n = len(arr)
    for i in range(n):
        swapped = False
        for j in range(n - 1 - i):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                swapped = True
        if not swapped:  # Optimization: already sorted
            break
    return arr

print(bubble_sort([64, 34, 25, 12, 22, 11, 90]))

# %% [markdown]
# ---
#
# ## Insertion Sort
#
# Build sorted array one element at a time. **Good for nearly sorted data.**

# %%
def insertion_sort(arr):
    """O(n²) time, O(1) space"""
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    return arr

print(insertion_sort([64, 34, 25, 12, 22, 11, 90]))

# %% [markdown]
# ---
#
# ## Merge Sort
#
# Divide and conquer: split, sort halves, merge. **Guaranteed O(n log n).**

# %%
def merge_sort(arr):
    """O(n log n) time, O(n) space"""
    if len(arr) <= 1:
        return arr
    
    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])
    
    return merge(left, right)

def merge(left, right):
    """Merge two sorted arrays."""
    result = []
    i = j = 0
    
    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    
    result.extend(left[i:])
    result.extend(right[j:])
    return result

print(merge_sort([64, 34, 25, 12, 22, 11, 90]))

# %% [markdown]
# ---
#
# ## Quick Sort
#
# Divide and conquer using pivot. **Fastest in practice for most cases.**

# %%
def quick_sort(arr):
    """O(n log n) average, O(n²) worst"""
    if len(arr) <= 1:
        return arr
    
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    
    return quick_sort(left) + middle + quick_sort(right)

print(quick_sort([64, 34, 25, 12, 22, 11, 90]))

# %%
# In-place quick sort (more efficient)
def quick_sort_inplace(arr, low=0, high=None):
    if high is None:
        high = len(arr) - 1
    
    if low < high:
        pivot_idx = partition(arr, low, high)
        quick_sort_inplace(arr, low, pivot_idx - 1)
        quick_sort_inplace(arr, pivot_idx + 1, high)
    return arr

def partition(arr, low, high):
    pivot = arr[high]
    i = low - 1
    
    for j in range(low, high):
        if arr[j] <= pivot:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]
    
    arr[i + 1], arr[high] = arr[high], arr[i + 1]
    return i + 1

print(quick_sort_inplace([64, 34, 25, 12, 22, 11, 90]))

# %% [markdown]
# ---
#
# ## Python's Built-in Sorting
#
# Python uses **Timsort** (hybrid of merge sort and insertion sort).

# %%
# sorted() - returns new list
nums = [3, 1, 4, 1, 5, 9, 2, 6]
print(f"sorted(): {sorted(nums)}")
print(f"Original: {nums}")

# .sort() - modifies in place
nums.sort()
print(f"After .sort(): {nums}")

# Custom key function
words = ["banana", "apple", "cherry"]
print(f"By length: {sorted(words, key=len)}")
print(f"Reverse: {sorted(words, reverse=True)}")

# Sort by multiple criteria
students = [("Alice", 85), ("Bob", 90), ("Charlie", 85)]
print(f"By score, then name: {sorted(students, key=lambda x: (-x[1], x[0]))}")

# %% [markdown]
# ---
#
# ## Key Takeaways
#
# | Algorithm | Best For |
# |-----------|----------|
# | **Insertion Sort** | Small or nearly sorted arrays |
# | **Merge Sort** | Guaranteed O(n log n), stable |
# | **Quick Sort** | General purpose, fastest average |
# | **Python's sorted()** | Use this in practice! |
