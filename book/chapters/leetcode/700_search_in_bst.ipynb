# %% [markdown]
# # 700. Search in a Binary Search Tree
#
# **Difficulty**: Easy
# **Topics**: Tree, BST, Binary Tree
# **Link**: [LeetCode 700](https://leetcode.com/problems/search-in-a-binary-search-tree/)
#
# ---
#
# ## Problem Statement
#
# You are given the `root` of a binary search tree (BST) and an integer `val`.
#
# Find the node in the BST that the node's value equals `val` and return the subtree rooted with that node. If such a node does not exist, return `null`.
#
# ### Constraints
#
# - The number of nodes is in the range `[1, 5000]`
# - `1 <= Node.val <= 10^7`
# - `root` is a binary search tree

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def search_bst(root: TreeNode, val: int) -> TreeNode:
    """BST search: O(h)"""
    while root:
        if val == root.val:
            return root
        elif val < root.val:
            root = root.left
        else:
            root = root.right
    return None

# %% [markdown]
# ---
#
# ## Key Takeaways
#
# | Pattern | When to Use |
# |---------|-------------|
# | **BST property** | Go left if smaller, right if larger |
