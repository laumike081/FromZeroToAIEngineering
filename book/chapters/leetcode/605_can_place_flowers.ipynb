# %% [markdown]
# # 605. Can Place Flowers
#
# **Difficulty**: Easy
# **Topics**: Array, Greedy
# **Link**: [LeetCode 605](https://leetcode.com/problems/can-place-flowers/)
#
# ---
#
# ## Problem Statement
#
# You have a long flowerbed in which some of the plots are planted, and some are not. However, flowers cannot be planted in **adjacent** plots.
#
# Given an integer array `flowerbed` containing `0`'s and `1`'s, where `0` means empty and `1` means not empty, and an integer `n`, return `true` if `n` new flowers can be planted in the `flowerbed` without violating the no-adjacent-flowers rule and `false` otherwise.
#
# ### Examples
#
# **Example 1:**
# ```
# Input: flowerbed = [1,0,0,0,1], n = 1
# Output: true
# ```
#
# **Example 2:**
# ```
# Input: flowerbed = [1,0,0,0,1], n = 2
# Output: false
# ```
#
# ### Constraints
#
# - `1 <= flowerbed.length <= 2 * 10^4`
# - `flowerbed[i]` is `0` or `1`
# - There are no two adjacent flowers in `flowerbed`
# - `0 <= n <= flowerbed.length`

# %% [markdown]
# ---
#
# ## Approach: Greedy
#
# ### Intuition
#
# Greedily plant flowers whenever possible:
# - A spot is valid if it's empty AND both neighbors are empty (or out of bounds)
# - Plant and count, return early if we reach `n`
#
# ### Complexity
# - **Time**: O(n)
# - **Space**: O(1)

# %%
def can_place_flowers(flowerbed: list[int], n: int) -> bool:
    """Greedy: O(n) time, O(1) space"""
    count = 0
    length = len(flowerbed)
    
    for i in range(length):
        if flowerbed[i] == 0:
            # Check left neighbor (or edge)
            left_empty = (i == 0) or (flowerbed[i - 1] == 0)
            # Check right neighbor (or edge)
            right_empty = (i == length - 1) or (flowerbed[i + 1] == 0)
            
            if left_empty and right_empty:
                flowerbed[i] = 1  # Plant flower
                count += 1
                
                if count >= n:
                    return True
    
    return count >= n

# Test
print(can_place_flowers([1, 0, 0, 0, 1], 1))  # True
print(can_place_flowers([1, 0, 0, 0, 1], 2))  # False

# %% [markdown]
# ---
#
# ## Walkthrough
#
# Input: `[1, 0, 0, 0, 1]`, n = 1
#
# | i | flowerbed[i] | left | right | Can plant? |
# |---|--------------|------|-------|------------|
# | 0 | 1 | - | - | No (occupied) |
# | 1 | 0 | 1 | 0 | No (left=1) |
# | 2 | 0 | 0 | 0 | **Yes!** Plant here |
# | - | - | - | - | count=1 >= n=1, return True |

# %% [markdown]
# ---
#
# ## Key Takeaways
#
# | Pattern | When to Use |
# |---------|-------------|
# | **Greedy placement** | Maximize count with local constraints |
# | **Boundary check** | Treat edges as empty neighbors |
