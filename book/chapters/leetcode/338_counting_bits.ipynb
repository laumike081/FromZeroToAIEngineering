# %% [markdown]
# # 338. Counting Bits
#
# **Difficulty**: Easy
# **Topics**: Dynamic Programming, Bit Manipulation
# **Link**: [LeetCode 338](https://leetcode.com/problems/counting-bits/)
#
# ---
#
# ## Problem Statement
#
# Given an integer `n`, return an array `ans` of length `n + 1` such that for each `i` (`0 <= i <= n`), `ans[i]` is the **number of 1's** in the binary representation of `i`.
#
# ### Examples
#
# **Example 1:**
# ```
# Input: n = 2
# Output: [0,1,1]
# Explanation:
# 0 --> 0
# 1 --> 1
# 2 --> 10
# ```
#
# **Example 2:**
# ```
# Input: n = 5
# Output: [0,1,1,2,1,2]
# Explanation:
# 0 --> 0
# 1 --> 1
# 2 --> 10
# 3 --> 11
# 4 --> 100
# 5 --> 101
# ```
#
# ### Constraints
#
# - `0 <= n <= 10^5`
#
# **Follow up:**
# - Can you do it in O(n) time and O(1) extra space (not counting the output array)?

# %% [markdown]
# ---
#
# ## Approach 1: DP with Last Set Bit
#
# ### Intuition
#
# Key insight: `i & (i - 1)` removes the last set bit from `i`.
#
# So: `countBits(i) = countBits(i & (i-1)) + 1`
#
# ### Complexity
# - **Time**: O(n)
# - **Space**: O(1) extra (output array doesn't count)

# %%
def count_bits(n: int) -> list[int]:
    """DP with last set bit: O(n) time"""
    ans = [0] * (n + 1)
    
    for i in range(1, n + 1):
        # i & (i-1) removes last set bit
        # So bits[i] = bits[i & (i-1)] + 1
        ans[i] = ans[i & (i - 1)] + 1
    
    return ans

# Test
print(count_bits(2))  # [0, 1, 1]
print(count_bits(5))  # [0, 1, 1, 2, 1, 2]

# %% [markdown]
# ---
#
# ## Approach 2: DP with Right Shift
#
# ### Intuition
#
# `i >> 1` is `i` divided by 2 (right shift removes last bit).
#
# So: `countBits(i) = countBits(i >> 1) + (i & 1)`
#
# The `(i & 1)` adds 1 if the last bit is set.

# %%
def count_bits_shift(n: int) -> list[int]:
    """DP with right shift"""
    ans = [0] * (n + 1)
    
    for i in range(1, n + 1):
        # bits[i] = bits[i // 2] + last bit
        ans[i] = ans[i >> 1] + (i & 1)
    
    return ans

# Test
print(count_bits_shift(5))  # [0, 1, 1, 2, 1, 2]

# %% [markdown]
# ---
#
# ## Walkthrough
#
# Using `ans[i] = ans[i & (i-1)] + 1`:
#
# | i | Binary | i & (i-1) | ans[i & (i-1)] | ans[i] |
# |---|--------|-----------|----------------|--------|
# | 0 | 0 | - | - | 0 |
# | 1 | 1 | 0 | 0 | 1 |
# | 2 | 10 | 0 | 0 | 1 |
# | 3 | 11 | 2 | 1 | 2 |
# | 4 | 100 | 0 | 0 | 1 |
# | 5 | 101 | 4 | 1 | 2 |

# %%
def count_bits_verbose(n: int) -> list[int]:
    """Verbose version"""
    ans = [0] * (n + 1)
    
    print(f"{'i':<4} {'binary':<8} {'i&(i-1)':<8} {'ans[i&(i-1)]':<12} {'ans[i]'}")
    print("-" * 45)
    print(f"{0:<4} {'0':<8} {'-':<8} {'-':<12} {0}")
    
    for i in range(1, n + 1):
        prev = i & (i - 1)
        ans[i] = ans[prev] + 1
        print(f"{i:<4} {bin(i)[2:]:<8} {prev:<8} {ans[prev]:<12} {ans[i]}")
    
    return ans

count_bits_verbose(5)

# %% [markdown]
# ---
#
# ## Bit Manipulation Tricks
#
# | Operation | Effect | Example |
# |-----------|--------|--------|
# | `i & (i-1)` | Remove last set bit | 6 (110) → 4 (100) |
# | `i >> 1` | Divide by 2 | 5 (101) → 2 (10) |
# | `i & 1` | Get last bit | 5 (101) → 1 |

# %% [markdown]
# ---
#
# ## Related Problems
#
# - [191. Number of 1 Bits](https://leetcode.com/problems/number-of-1-bits/) - Easy
# - [190. Reverse Bits](https://leetcode.com/problems/reverse-bits/) - Easy
# - [1356. Sort Integers by The Number of 1 Bits](https://leetcode.com/problems/sort-integers-by-the-number-of-1-bits/) - Easy

# %% [markdown]
# ---
#
# ## Key Takeaways
#
# | Pattern | When to Use |
# |---------|-------------|
# | **`i & (i-1)`** | Remove last set bit |
# | **DP on bits** | Build answer from smaller numbers |
# | **Right shift** | Relate number to its half |
