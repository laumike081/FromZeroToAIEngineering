# %% [markdown]
# # 649. Dota2 Senate
#
# **Difficulty**: Medium
# **Topics**: String, Greedy, Queue
# **Link**: [LeetCode 649](https://leetcode.com/problems/dota2-senate/)
#
# ---
#
# ## Problem Statement
#
# In the world of Dota2, there are two parties: the Radiant and the Dire.
#
# The Dota2 senate consists of senators coming from two parties. Now the Senate wants to decide on a change in the Dota2 game. The voting for this change is a round-based procedure.
#
# Each senator can exercise one of the two rights:
# 1. **Ban** one senator's right: A senator can make another senator lose all his rights in this and all the following rounds.
# 2. **Announce the victory**: If this senator found the senators who still have rights to vote are all from the same party, he can announce the victory.
#
# Given a string `senate` representing each senator's party. Return which party will finally announce the victory.
#
# ### Examples
#
# **Example 1:**
# ```
# Input: senate = "RD"
# Output: "Radiant"
# ```
#
# **Example 2:**
# ```
# Input: senate = "RDD"
# Output: "Dire"
# ```
#
# ### Constraints
#
# - `1 <= senate.length <= 10^4`
# - `senate[i]` is either `'R'` or `'D'`

# %% [markdown]
# ---
#
# ## Approach: Two Queues
#
# ### Intuition
#
# Use two queues to track indices of R and D senators. In each round, the senator with smaller index bans the other and goes to the next round.
#
# ### Complexity
# - **Time**: O(n)
# - **Space**: O(n)

# %%
from collections import deque

def predict_party_victory(senate: str) -> str:
    """Two queues: O(n)"""
    n = len(senate)
    radiant = deque()
    dire = deque()
    
    for i, s in enumerate(senate):
        if s == 'R':
            radiant.append(i)
        else:
            dire.append(i)
    
    while radiant and dire:
        r_idx = radiant.popleft()
        d_idx = dire.popleft()
        
        # Smaller index bans the other, then goes to next round
        if r_idx < d_idx:
            radiant.append(r_idx + n)  # Add n for next round
        else:
            dire.append(d_idx + n)
    
    return "Radiant" if radiant else "Dire"

# Test
print(predict_party_victory("RD"))   # Radiant
print(predict_party_victory("RDD"))  # Dire

# %% [markdown]
# ---
#
# ## Key Takeaways
#
# | Pattern | When to Use |
# |---------|-------------|
# | **Two queues** | Simulate round-robin with two groups |
# | **Add n for next round** | Maintain relative ordering |
