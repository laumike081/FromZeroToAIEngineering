# %% [markdown]
# # 53. Maximum Subarray
#
# **Difficulty**: Medium
# **Topics**: Array, Divide and Conquer, Dynamic Programming
# **Link**: [LeetCode 53](https://leetcode.com/problems/maximum-subarray/)
#
# ---
#
# ## Problem Statement
#
# Given an integer array `nums`, find the subarray with the largest sum, and return *its sum*.
#
# ### Examples
#
# **Example 1:**
# ```
# Input: nums = [-2,1,-3,4,-1,2,1,-5,4]
# Output: 6
# Explanation: The subarray [4,-1,2,1] has the largest sum 6.
# ```
#
# **Example 2:**
# ```
# Input: nums = [1]
# Output: 1
# ```
#
# **Example 3:**
# ```
# Input: nums = [5,4,-1,7,8]
# Output: 23
# Explanation: The subarray [5,4,-1,7,8] has the largest sum 23.
# ```
#
# ### Constraints
#
# - `1 <= nums.length <= 10^5`
# - `-10^4 <= nums[i] <= 10^4`

# %% [markdown]
# ---
#
# ## Approach: Kadane's Algorithm
#
# ### Intuition
#
# At each position, we have two choices:
# 1. **Extend** the current subarray (add current element)
# 2. **Start fresh** from the current element
#
# We choose whichever gives a larger sum:
# ```
# current_sum = max(nums[i], current_sum + nums[i])
# ```
#
# ### Key Insight
#
# If `current_sum` becomes negative, it's better to start fresh. A negative prefix can only hurt future sums.
#
# ### Complexity
# - **Time**: O(n) - single pass
# - **Space**: O(1) - two variables

# %%
def max_subarray(nums: list[int]) -> int:
    """Kadane's Algorithm: O(n) time, O(1) space"""
    current_sum = nums[0]
    max_sum = nums[0]
    
    for i in range(1, len(nums)):
        # Either extend current subarray or start fresh
        current_sum = max(nums[i], current_sum + nums[i])
        
        # Update global maximum
        max_sum = max(max_sum, current_sum)
    
    return max_sum

# Test
print(max_subarray([-2, 1, -3, 4, -1, 2, 1, -5, 4]))  # 6
print(max_subarray([1]))                              # 1
print(max_subarray([5, 4, -1, 7, 8]))                 # 23

# %% [markdown]
# ---
#
# ## Walkthrough
#
# Input: `[-2, 1, -3, 4, -1, 2, 1, -5, 4]`
#
# | i | nums[i] | current_sum | max_sum | Decision |
# |---|---------|-------------|---------|----------|
# | 0 | -2 | -2 | -2 | Start |
# | 1 | 1 | max(1, -2+1) = 1 | 1 | Start fresh |
# | 2 | -3 | max(-3, 1-3) = -2 | 1 | Extend |
# | 3 | 4 | max(4, -2+4) = 4 | 4 | Start fresh |
# | 4 | -1 | max(-1, 4-1) = 3 | 4 | Extend |
# | 5 | 2 | max(2, 3+2) = 5 | 5 | Extend |
# | 6 | 1 | max(1, 5+1) = **6** | **6** | Extend |
# | 7 | -5 | max(-5, 6-5) = 1 | 6 | Extend |
# | 8 | 4 | max(4, 1+4) = 5 | 6 | Extend |
#
# **Result**: 6 (subarray `[4, -1, 2, 1]`)

# %%
def max_subarray_verbose(nums: list[int]) -> int:
    """Verbose version showing the process"""
    current_sum = nums[0]
    max_sum = nums[0]
    start = end = 0
    temp_start = 0
    
    print(f"{'i':<3} {'num':<5} {'curr':<6} {'max':<5} {'decision'}")
    print("-" * 35)
    print(f"{0:<3} {nums[0]:<5} {current_sum:<6} {max_sum:<5} start")
    
    for i in range(1, len(nums)):
        if nums[i] > current_sum + nums[i]:
            current_sum = nums[i]
            temp_start = i
            decision = "fresh"
        else:
            current_sum = current_sum + nums[i]
            decision = "extend"
        
        if current_sum > max_sum:
            max_sum = current_sum
            start = temp_start
            end = i
        
        print(f"{i:<3} {nums[i]:<5} {current_sum:<6} {max_sum:<5} {decision}")
    
    print(f"\nMax subarray: {nums[start:end+1]} = {max_sum}")
    return max_sum

max_subarray_verbose([-2, 1, -3, 4, -1, 2, 1, -5, 4])

# %% [markdown]
# ---
#
# ## Alternative: Return the Subarray Itself

# %%
def max_subarray_with_indices(nums: list[int]) -> tuple[int, int, int]:
    """Return (max_sum, start_index, end_index)"""
    current_sum = nums[0]
    max_sum = nums[0]
    start = end = 0
    temp_start = 0
    
    for i in range(1, len(nums)):
        if nums[i] > current_sum + nums[i]:
            current_sum = nums[i]
            temp_start = i
        else:
            current_sum += nums[i]
        
        if current_sum > max_sum:
            max_sum = current_sum
            start = temp_start
            end = i
    
    return max_sum, start, end

nums = [-2, 1, -3, 4, -1, 2, 1, -5, 4]
max_sum, start, end = max_subarray_with_indices(nums)
print(f"Max sum: {max_sum}")
print(f"Subarray: {nums[start:end+1]}")

# %% [markdown]
# ---
#
# ## Common Mistakes
#
# 1. **Initializing to 0** - fails for all-negative arrays like `[-3, -2, -1]`
# 2. **Not handling single element** - edge case
# 3. **Confusing subarray vs subsequence** - subarray must be contiguous

# %% [markdown]
# ---
#
# ## Related Problems
#
# - [121. Best Time to Buy and Sell Stock](https://leetcode.com/problems/best-time-to-buy-and-sell-stock/) - Easy
# - [152. Maximum Product Subarray](https://leetcode.com/problems/maximum-product-subarray/) - Medium
# - [918. Maximum Sum Circular Subarray](https://leetcode.com/problems/maximum-sum-circular-subarray/) - Medium

# %% [markdown]
# ---
#
# ## Key Takeaways
#
# | Pattern | When to Use |
# |---------|-------------|
# | **Kadane's Algorithm** | Maximum subarray sum |
# | **Extend or restart** | DP with local vs global optimum |
# | **Negative prefix = bad** | Drop negative running sums |
