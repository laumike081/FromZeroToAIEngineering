# %% [markdown]
# # My first notebook
#
# ## Objectives
#
# - Confirm the notebook workflow works end-to-end.
# - Write a small piece of Python and capture the output.
#
# ## Notes
#
# Write what you learned in plain language.

# %%
import sys
print(sys.version)

# %% [markdown]
# ## Exercises
#
# - Change the code cell to print your platform info.
# - Add a second code cell that computes something small (e.g., a list comprehension).
